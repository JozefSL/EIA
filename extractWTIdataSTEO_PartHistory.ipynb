# %% [markdown]
# <a href="https://colab.research.google.com/github/JozefSL/EIA/blob/main/extractWTIdataSTEO_PartHistory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import os # Import the os module for file operations

url = 'https://www.eia.gov/outlooks/steo/outlook.php'

try:
    response = requests.get(url)
    response.raise_for_status()  # Raise an HTTPError for bad responses (4xx or 5xx)
    soup = BeautifulSoup(response.text, 'html.parser')

    print("Successfully fetched the webpage. Now looking for download links...")

    all_links = []
    for a_tag in soup.find_all('a', href=True):
        href = a_tag['href']
        # Resolve relative URLs to absolute URLs
        if not href.startswith('http'):
            href = requests.compat.urljoin(url, href)
        all_links.append(href)

    # Filter for historical forecast data files (ending in .xlsx or .xls and in archives)
    # and only keep files older than 2019.
    filtered_links = []
    for link in all_links:
        if 'archives' in link and (link.endswith('.xlsx') or link.endswith('.xls')):
            file_name = link.split('/')[-1]
            # Regex to find the two-digit year, e.g., 'sep25_base.xlsx' -> '25'
            match = re.search(r'[a-z]{3}(\d{2})_base\.(xlsx|xls)', file_name, re.IGNORECASE)
            if match:
                year_suffix = int(match.group(1))
                # We want files older than 2019, which means year suffix > 19 (e.g., 08 for 2008, 18 for 2018)
                if year_suffix > 19:
                    filtered_links.append(link)

    # Sort in reverse to process newest first, assuming this is desired for initial inspection
    historical_data_links = sorted(filtered_links, reverse=True)

    if historical_data_links:
        print(f"Found {len(historical_data_links)} potential historical forecast data links in archives (older than 2019).")
        print("Downloading and processing files...")

        all_extracted_rows = []

        for link_idx, link in enumerate(historical_data_links):
            file_name = link.split('/')[-1]
            print(f"({link_idx + 1}/{len(historical_data_links)}) Attempting to download {file_name} from: {link}")

            try:
                file_response = requests.get(link, stream=True)
                file_response.raise_for_status()

                with open(file_name, 'wb') as f:
                    for chunk in file_response.iter_content(chunk_size=8192):
                        f.write(chunk)
                print(f"Successfully downloaded {file_name}")

                # Read the '2tab' sheet into a pandas DataFrame without headers
                if file_name.endswith('.xlsx') or file_name.endswith('.xls'):
                    try:
                        df_raw = pd.read_excel(file_name, sheet_name='2tab', header=None)

                        # Extract relevant rows (0-indexed)
                        year_row = df_raw.iloc[2] # Row 3 in Excel
                        month_row = df_raw.iloc[3] # Row 4 in Excel
                        data_row = df_raw.iloc[5] # Row 6 in Excel

                        current_year = None
                        # Iterate through columns starting from the third column (index 2)
                        for col_idx in range(2, len(data_row)):
                            # Update current_year from row 3, handling merged cells (NaNs)
                            if pd.notna(year_row[col_idx]):
                                try:
                                    current_year = int(year_row[col_idx])
                                except ValueError:
                                    current_year = None # Reset if not a valid year number

                            month = month_row[col_idx]
                            value = data_row[col_idx]

                            # Only append if we have valid year, month, and value
                            if current_year is not None and pd.notna(month) and pd.notna(value):
                                all_extracted_rows.append({
                                    'Year': current_year,
                                    'Month': month,
                                    'Value': value,
                                    'Source_File': file_name
                                })
                        print(f"Successfully extracted data from '2tab' row 6 of {file_name}.")

                    except ValueError as ve:
                        print(f"Sheet '2tab' not found or other parsing error in {file_name}: {ve}")
                    except Exception as e:
                        print(f"Error reading Excel file {file_name} (sheet '2tab'): {e}")

                # Clean up the downloaded file after processing
                os.remove(file_name)
                print(f"Removed temporary file: {file_name}")

            except requests.exceptions.RequestException as e:
                print(f"Error downloading {file_name} from {link}: {e}")
            except Exception as e:
                print(f"An unexpected error occurred while processing {file_name}: {e}")

        if all_extracted_rows:
            print("\nConcatenating all extracted data into a final DataFrame...")
            final_df = pd.DataFrame(all_extracted_rows)
            print("Concatenation complete. Head of the final DataFrame:")
            print(final_df.head())
            print(f"Total rows in the combined DataFrame: {len(final_df)}")
        else:
            print("No data from '2tab' sheets could be read and concatenated.")

    else:
        print("No direct historical forecast data files (.xls, .xlsx) found in archives (older than 2019).")

except requests.exceptions.RequestException as e:
    print(f"Error fetching the URL or general request error: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Successfully fetched the webpage. Now looking for download links...
# Found 81 potential historical forecast data links in archives (older than 2019).
# Downloading and processing files...
# (1/81) Attempting to download sep26_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/sep26_base.xlsx
# Successfully downloaded sep26_base.xlsx
# Successfully extracted data from '2tab' row 6 of sep26_base.xlsx.
# Removed temporary file: sep26_base.xlsx
# (2/81) Attempting to download sep25_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/sep25_base.xlsx
# Successfully downloaded sep25_base.xlsx
# Successfully extracted data from '2tab' row 6 of sep25_base.xlsx.
# Removed temporary file: sep25_base.xlsx
# (3/81) Attempting to download sep24_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/sep24_base.xlsx
# Successfully downloaded sep24_base.xlsx
# Successfully extracted data from '2tab' row 6 of sep24_base.xlsx.
# Removed temporary file: sep24_base.xlsx
# (4/81) Attempting to download sep23_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/sep23_base.xlsx
# Successfully downloaded sep23_base.xlsx
# Successfully extracted data from '2tab' row 6 of sep23_base.xlsx.
# Removed temporary file: sep23_base.xlsx
# (5/81) Attempting to download sep22_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/sep22_base.xlsx
# Successfully downloaded sep22_base.xlsx
# Successfully extracted data from '2tab' row 6 of sep22_base.xlsx.
# Removed temporary file: sep22_base.xlsx
# (6/81) Attempting to download sep21_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/sep21_base.xlsx
# Successfully downloaded sep21_base.xlsx
# Successfully extracted data from '2tab' row 6 of sep21_base.xlsx.
# Removed temporary file: sep21_base.xlsx
# (7/81) Attempting to download sep20_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/sep20_base.xlsx
# Successfully downloaded sep20_base.xlsx
# Successfully extracted data from '2tab' row 6 of sep20_base.xlsx.
# Removed temporary file: sep20_base.xlsx
# (8/81) Attempting to download oct25_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/oct25_base.xlsx
# Successfully downloaded oct25_base.xlsx
# Successfully extracted data from '2tab' row 6 of oct25_base.xlsx.
# Removed temporary file: oct25_base.xlsx
# (9/81) Attempting to download oct24_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/oct24_base.xlsx
# Successfully downloaded oct24_base.xlsx
# Successfully extracted data from '2tab' row 6 of oct24_base.xlsx.
# Removed temporary file: oct24_base.xlsx
# (10/81) Attempting to download oct23_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/oct23_base.xlsx
# Successfully downloaded oct23_base.xlsx
# Successfully extracted data from '2tab' row 6 of oct23_base.xlsx.
# Removed temporary file: oct23_base.xlsx
# (11/81) Attempting to download oct22_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/oct22_base.xlsx
# Successfully downloaded oct22_base.xlsx
# Successfully extracted data from '2tab' row 6 of oct22_base.xlsx.
# Removed temporary file: oct22_base.xlsx
# (12/81) Attempting to download oct21_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/oct21_base.xlsx
# Successfully downloaded oct21_base.xlsx
# Successfully extracted data from '2tab' row 6 of oct21_base.xlsx.
# Removed temporary file: oct21_base.xlsx
# (13/81) Attempting to download oct20_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/oct20_base.xlsx
# Successfully downloaded oct20_base.xlsx
# Successfully extracted data from '2tab' row 6 of oct20_base.xlsx.
# Removed temporary file: oct20_base.xlsx
# (14/81) Attempting to download nov25_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/nov25_base.xlsx
# Successfully downloaded nov25_base.xlsx
# Successfully extracted data from '2tab' row 6 of nov25_base.xlsx.
# Removed temporary file: nov25_base.xlsx
# (15/81) Attempting to download nov24_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/nov24_base.xlsx
# Successfully downloaded nov24_base.xlsx
# Successfully extracted data from '2tab' row 6 of nov24_base.xlsx.
# Removed temporary file: nov24_base.xlsx
# (16/81) Attempting to download nov23_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/nov23_base.xlsx
# Successfully downloaded nov23_base.xlsx
# Successfully extracted data from '2tab' row 6 of nov23_base.xlsx.
# Removed temporary file: nov23_base.xlsx
# (17/81) Attempting to download nov22_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/nov22_base.xlsx
# Successfully downloaded nov22_base.xlsx
# Successfully extracted data from '2tab' row 6 of nov22_base.xlsx.
# Removed temporary file: nov22_base.xlsx
# (18/81) Attempting to download nov21_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/nov21_base.xlsx
# Successfully downloaded nov21_base.xlsx
# Successfully extracted data from '2tab' row 6 of nov21_base.xlsx.
# Removed temporary file: nov21_base.xlsx
# (19/81) Attempting to download nov20_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/nov20_base.xlsx
# Successfully downloaded nov20_base.xlsx
# Successfully extracted data from '2tab' row 6 of nov20_base.xlsx.
# Removed temporary file: nov20_base.xlsx
# (20/81) Attempting to download may26_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/may26_base.xlsx
# Successfully downloaded may26_base.xlsx
# Successfully extracted data from '2tab' row 6 of may26_base.xlsx.
# Removed temporary file: may26_base.xlsx
# (21/81) Attempting to download may25_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/may25_base.xlsx
# Successfully downloaded may25_base.xlsx
# Successfully extracted data from '2tab' row 6 of may25_base.xlsx.
# Removed temporary file: may25_base.xlsx
# (22/81) Attempting to download may24_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/may24_base.xlsx
# Successfully downloaded may24_base.xlsx
# Successfully extracted data from '2tab' row 6 of may24_base.xlsx.
# Removed temporary file: may24_base.xlsx
# (23/81) Attempting to download may23_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/may23_base.xlsx
# Successfully downloaded may23_base.xlsx
# Successfully extracted data from '2tab' row 6 of may23_base.xlsx.
# Removed temporary file: may23_base.xlsx
# (24/81) Attempting to download may22_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/may22_base.xlsx
# Successfully downloaded may22_base.xlsx
# Successfully extracted data from '2tab' row 6 of may22_base.xlsx.
# Removed temporary file: may22_base.xlsx
# (25/81) Attempting to download may21_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/may21_base.xlsx
# Successfully downloaded may21_base.xlsx
# Successfully extracted data from '2tab' row 6 of may21_base.xlsx.
# Removed temporary file: may21_base.xlsx
# (26/81) Attempting to download may20_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/may20_base.xlsx
# Successfully downloaded may20_base.xlsx
# Successfully extracted data from '2tab' row 6 of may20_base.xlsx.
# Removed temporary file: may20_base.xlsx
# (27/81) Attempting to download mar26_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/mar26_base.xlsx
# Successfully downloaded mar26_base.xlsx
# Successfully extracted data from '2tab' row 6 of mar26_base.xlsx.
# Removed temporary file: mar26_base.xlsx
# (28/81) Attempting to download mar25_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/mar25_base.xlsx
# Successfully downloaded mar25_base.xlsx
# Successfully extracted data from '2tab' row 6 of mar25_base.xlsx.
# Removed temporary file: mar25_base.xlsx
# (29/81) Attempting to download mar24_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/mar24_base.xlsx
# Successfully downloaded mar24_base.xlsx
# Successfully extracted data from '2tab' row 6 of mar24_base.xlsx.
# Removed temporary file: mar24_base.xlsx
# (30/81) Attempting to download mar23_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/mar23_base.xlsx
# Successfully downloaded mar23_base.xlsx
# Successfully extracted data from '2tab' row 6 of mar23_base.xlsx.
# Removed temporary file: mar23_base.xlsx
# (31/81) Attempting to download mar22_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/mar22_base.xlsx
# Successfully downloaded mar22_base.xlsx
# Successfully extracted data from '2tab' row 6 of mar22_base.xlsx.
# Removed temporary file: mar22_base.xlsx
# (32/81) Attempting to download mar21_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/mar21_base.xlsx
# Successfully downloaded mar21_base.xlsx
# Successfully extracted data from '2tab' row 6 of mar21_base.xlsx.
# Removed temporary file: mar21_base.xlsx
# (33/81) Attempting to download mar20_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/mar20_base.xlsx
# Successfully downloaded mar20_base.xlsx
# Successfully extracted data from '2tab' row 6 of mar20_base.xlsx.
# Removed temporary file: mar20_base.xlsx
# (34/81) Attempting to download jun26_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jun26_base.xlsx
# Successfully downloaded jun26_base.xlsx
# Successfully extracted data from '2tab' row 6 of jun26_base.xlsx.
# Removed temporary file: jun26_base.xlsx
# (35/81) Attempting to download jun25_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jun25_base.xlsx
# Successfully downloaded jun25_base.xlsx
# Successfully extracted data from '2tab' row 6 of jun25_base.xlsx.
# Removed temporary file: jun25_base.xlsx
# (36/81) Attempting to download jun24_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jun24_base.xlsx
# Successfully downloaded jun24_base.xlsx
# Successfully extracted data from '2tab' row 6 of jun24_base.xlsx.
# Removed temporary file: jun24_base.xlsx
# (37/81) Attempting to download jun23_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jun23_base.xlsx
# Successfully downloaded jun23_base.xlsx
# Successfully extracted data from '2tab' row 6 of jun23_base.xlsx.
# Removed temporary file: jun23_base.xlsx
# (38/81) Attempting to download jun22_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jun22_base.xlsx
# Successfully downloaded jun22_base.xlsx
# Successfully extracted data from '2tab' row 6 of jun22_base.xlsx.
# Removed temporary file: jun22_base.xlsx
# (39/81) Attempting to download jun21_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jun21_base.xlsx
# Successfully downloaded jun21_base.xlsx
# Successfully extracted data from '2tab' row 6 of jun21_base.xlsx.
# Removed temporary file: jun21_base.xlsx
# (40/81) Attempting to download jun20_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jun20_base.xlsx
# Successfully downloaded jun20_base.xlsx
# Successfully extracted data from '2tab' row 6 of jun20_base.xlsx.
# Removed temporary file: jun20_base.xlsx
# (41/81) Attempting to download jul26_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jul26_base.xlsx
# Successfully downloaded jul26_base.xlsx
# Successfully extracted data from '2tab' row 6 of jul26_base.xlsx.
# Removed temporary file: jul26_base.xlsx
# (42/81) Attempting to download jul25_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jul25_base.xlsx
# Successfully downloaded jul25_base.xlsx
# Successfully extracted data from '2tab' row 6 of jul25_base.xlsx.
# Removed temporary file: jul25_base.xlsx
# (43/81) Attempting to download jul24_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jul24_base.xlsx
# Successfully downloaded jul24_base.xlsx
# Successfully extracted data from '2tab' row 6 of jul24_base.xlsx.
# Removed temporary file: jul24_base.xlsx
# (44/81) Attempting to download jul23_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jul23_base.xlsx
# Successfully downloaded jul23_base.xlsx
# Successfully extracted data from '2tab' row 6 of jul23_base.xlsx.
# Removed temporary file: jul23_base.xlsx
# (45/81) Attempting to download jul22_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jul22_base.xlsx
# Successfully downloaded jul22_base.xlsx
# Successfully extracted data from '2tab' row 6 of jul22_base.xlsx.
# Removed temporary file: jul22_base.xlsx
# (46/81) Attempting to download jul21_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jul21_base.xlsx
# Successfully downloaded jul21_base.xlsx
# Successfully extracted data from '2tab' row 6 of jul21_base.xlsx.
# Removed temporary file: jul21_base.xlsx
# (47/81) Attempting to download jul20_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jul20_base.xlsx
# Successfully downloaded jul20_base.xlsx
# Successfully extracted data from '2tab' row 6 of jul20_base.xlsx.
# Removed temporary file: jul20_base.xlsx
# (48/81) Attempting to download jan26_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jan26_base.xlsx
# Successfully downloaded jan26_base.xlsx
# Successfully extracted data from '2tab' row 6 of jan26_base.xlsx.
# Removed temporary file: jan26_base.xlsx
# (49/81) Attempting to download jan25_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jan25_base.xlsx
# Successfully downloaded jan25_base.xlsx
# Successfully extracted data from '2tab' row 6 of jan25_base.xlsx.
# Removed temporary file: jan25_base.xlsx
# (50/81) Attempting to download jan24_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jan24_base.xlsx
# Successfully downloaded jan24_base.xlsx
# Successfully extracted data from '2tab' row 6 of jan24_base.xlsx.
# Removed temporary file: jan24_base.xlsx
# (51/81) Attempting to download jan23_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jan23_base.xlsx
# Successfully downloaded jan23_base.xlsx
# Successfully extracted data from '2tab' row 6 of jan23_base.xlsx.
# Removed temporary file: jan23_base.xlsx
# (52/81) Attempting to download jan22_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jan22_base.xlsx
# Successfully downloaded jan22_base.xlsx
# Successfully extracted data from '2tab' row 6 of jan22_base.xlsx.
# Removed temporary file: jan22_base.xlsx
# (53/81) Attempting to download jan21_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jan21_base.xlsx
# Successfully downloaded jan21_base.xlsx
# Successfully extracted data from '2tab' row 6 of jan21_base.xlsx.
# Removed temporary file: jan21_base.xlsx
# (54/81) Attempting to download jan20_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/jan20_base.xlsx
# Successfully downloaded jan20_base.xlsx
# Successfully extracted data from '2tab' row 6 of jan20_base.xlsx.
# Removed temporary file: jan20_base.xlsx
# (55/81) Attempting to download feb26_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/feb26_base.xlsx
# Successfully downloaded feb26_base.xlsx
# Successfully extracted data from '2tab' row 6 of feb26_base.xlsx.
# Removed temporary file: feb26_base.xlsx
# (56/81) Attempting to download feb25_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/feb25_base.xlsx
# Successfully downloaded feb25_base.xlsx
# Successfully extracted data from '2tab' row 6 of feb25_base.xlsx.
# Removed temporary file: feb25_base.xlsx
# (57/81) Attempting to download feb24_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/feb24_base.xlsx
# Successfully downloaded feb24_base.xlsx
# Successfully extracted data from '2tab' row 6 of feb24_base.xlsx.
# Removed temporary file: feb24_base.xlsx
# (58/81) Attempting to download feb23_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/feb23_base.xlsx
# Successfully downloaded feb23_base.xlsx
# Successfully extracted data from '2tab' row 6 of feb23_base.xlsx.
# Removed temporary file: feb23_base.xlsx
# (59/81) Attempting to download feb22_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/feb22_base.xlsx
# Successfully downloaded feb22_base.xlsx
# Successfully extracted data from '2tab' row 6 of feb22_base.xlsx.
# Removed temporary file: feb22_base.xlsx
# (60/81) Attempting to download feb21_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/feb21_base.xlsx
# Successfully downloaded feb21_base.xlsx
# Successfully extracted data from '2tab' row 6 of feb21_base.xlsx.
# Removed temporary file: feb21_base.xlsx
# (61/81) Attempting to download feb20_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/feb20_base.xlsx
# Successfully downloaded feb20_base.xlsx
# Successfully extracted data from '2tab' row 6 of feb20_base.xlsx.
# Removed temporary file: feb20_base.xlsx
# (62/81) Attempting to download dec25_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/dec25_base.xlsx
# Successfully downloaded dec25_base.xlsx
# Successfully extracted data from '2tab' row 6 of dec25_base.xlsx.
# Removed temporary file: dec25_base.xlsx
# (63/81) Attempting to download dec24_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/dec24_base.xlsx
# Successfully downloaded dec24_base.xlsx
# Successfully extracted data from '2tab' row 6 of dec24_base.xlsx.
# Removed temporary file: dec24_base.xlsx
# (64/81) Attempting to download dec23_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/dec23_base.xlsx
# Successfully downloaded dec23_base.xlsx
# Successfully extracted data from '2tab' row 6 of dec23_base.xlsx.
# Removed temporary file: dec23_base.xlsx
# (65/81) Attempting to download dec22_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/dec22_base.xlsx
# Successfully downloaded dec22_base.xlsx
# Successfully extracted data from '2tab' row 6 of dec22_base.xlsx.
# Removed temporary file: dec22_base.xlsx
# (66/81) Attempting to download dec21_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/dec21_base.xlsx
# Successfully downloaded dec21_base.xlsx
# Successfully extracted data from '2tab' row 6 of dec21_base.xlsx.
# Removed temporary file: dec21_base.xlsx
# (67/81) Attempting to download dec20_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/dec20_base.xlsx
# Successfully downloaded dec20_base.xlsx
# Successfully extracted data from '2tab' row 6 of dec20_base.xlsx.
# Removed temporary file: dec20_base.xlsx
# (68/81) Attempting to download aug26_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/aug26_base.xlsx
# Successfully downloaded aug26_base.xlsx
# Successfully extracted data from '2tab' row 6 of aug26_base.xlsx.
# Removed temporary file: aug26_base.xlsx
# (69/81) Attempting to download aug25_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/aug25_base.xlsx
# Successfully downloaded aug25_base.xlsx
# Successfully extracted data from '2tab' row 6 of aug25_base.xlsx.
# Removed temporary file: aug25_base.xlsx
# (70/81) Attempting to download aug24_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/aug24_base.xlsx
# Successfully downloaded aug24_base.xlsx
# Successfully extracted data from '2tab' row 6 of aug24_base.xlsx.
# Removed temporary file: aug24_base.xlsx
# (71/81) Attempting to download aug23_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/aug23_base.xlsx
# Successfully downloaded aug23_base.xlsx
# Successfully extracted data from '2tab' row 6 of aug23_base.xlsx.
# Removed temporary file: aug23_base.xlsx
# (72/81) Attempting to download aug22_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/aug22_base.xlsx
# Successfully downloaded aug22_base.xlsx
# Successfully extracted data from '2tab' row 6 of aug22_base.xlsx.
# Removed temporary file: aug22_base.xlsx
# (73/81) Attempting to download aug21_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/aug21_base.xlsx
# Successfully downloaded aug21_base.xlsx
# Successfully extracted data from '2tab' row 6 of aug21_base.xlsx.
# Removed temporary file: aug21_base.xlsx
# (74/81) Attempting to download aug20_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/aug20_base.xlsx
# Successfully downloaded aug20_base.xlsx
# Successfully extracted data from '2tab' row 6 of aug20_base.xlsx.
# Removed temporary file: aug20_base.xlsx
# (75/81) Attempting to download apr26_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/apr26_base.xlsx
# Successfully downloaded apr26_base.xlsx
# Successfully extracted data from '2tab' row 6 of apr26_base.xlsx.
# Removed temporary file: apr26_base.xlsx
# (76/81) Attempting to download apr25_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/apr25_base.xlsx
# Successfully downloaded apr25_base.xlsx
# Successfully extracted data from '2tab' row 6 of apr25_base.xlsx.
# Removed temporary file: apr25_base.xlsx
# (77/81) Attempting to download apr24_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/apr24_base.xlsx
# Successfully downloaded apr24_base.xlsx
# Successfully extracted data from '2tab' row 6 of apr24_base.xlsx.
# Removed temporary file: apr24_base.xlsx
# (78/81) Attempting to download apr23_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/apr23_base.xlsx
# Successfully downloaded apr23_base.xlsx
# Successfully extracted data from '2tab' row 6 of apr23_base.xlsx.
# Removed temporary file: apr23_base.xlsx
# (79/81) Attempting to download apr22_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/apr22_base.xlsx
# Successfully downloaded apr22_base.xlsx
# Successfully extracted data from '2tab' row 6 of apr22_base.xlsx.
# Removed temporary file: apr22_base.xlsx
# (80/81) Attempting to download apr21_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/apr21_base.xlsx
# Successfully downloaded apr21_base.xlsx
# Successfully extracted data from '2tab' row 6 of apr21_base.xlsx.
# Removed temporary file: apr21_base.xlsx
# (81/81) Attempting to download apr20_base.xlsx from: https://www.eia.gov/outlooks/steo/archives/apr20_base.xlsx
# Successfully downloaded apr20_base.xlsx
# Successfully extracted data from '2tab' row 6 of apr20_base.xlsx.
# Removed temporary file: apr20_base.xlsx
#
# Concatenating all extracted data into a final DataFrame...
# Concatenation complete. Head of the final DataFrame:
#    Year Month   Value      Source_File
# 0  2022   Jan   83.22  sep26_base.xlsx
# 1  2022   Feb   91.64  sep26_base.xlsx
# 2  2022   Mar  108.50  sep26_base.xlsx
# 3  2022   Apr  101.78  sep26_base.xlsx
# 4  2022   May  109.55  sep26_base.xlsx
# Total rows in the combined DataFrame: 5832

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the average annual 'Value'
annual_avg_value = final_df.groupby('Year')['Value'].mean().reset_index()

# Plotting the average annual 'Value'
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Value', data=annual_avg_value, marker='o')
plt.title('Average Annual Value Over Time')
plt.xlabel('Year')
plt.ylabel('Average Value')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
final_df.head()
# Out:
#    Year Month   Value      Source_File
# 0  2022   Jan   83.22  sep26_base.xlsx
# 1  2022   Feb   91.64  sep26_base.xlsx
# 2  2022   Mar  108.50  sep26_base.xlsx
# 3  2022   Apr  101.78  sep26_base.xlsx
# 4  2022   May  109.55  sep26_base.xlsx

# %%
import plotly.express as px
import pandas as pd

# Filter the DataFrame for 'aug25_base.xlsx'
df_aug25 = final_df[final_df['Source_File'] == 'aug25_base.xlsx'].copy()

# Ensure 'Year' is integer and 'Month' is string for plotting
df_aug25['Year'] = df_aug25['Year'].astype(int)

# Create a date-like column for better time series plotting
# Assuming 'Month' is a month name, we can map it to a number or concatenate with year
month_to_num = {
    'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6,
    'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12
}
df_aug25['Month_Num'] = df_aug25['Month'].map(month_to_num)

# Create a 'Date' column for plotting
df_aug25['Date'] = pd.to_datetime(df_aug25['Year'].astype(str) + '-' + df_aug25['Month_Num'].astype(str) + '-01')

# Sort by Date to ensure correct plotting order
df_aug25 = df_aug25.sort_values(by='Date')

# Plotting the 'Value' for 'aug25_base.xlsx' over time using Plotly Express for interactivity
fig = px.line(df_aug25, x='Date', y='Value', title='Value Over Time for Source File: aug25_base.xlsx',
              hover_data={'Date': '|%Y-%m-%d', 'Value': True})

fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Value',
    xaxis_tickformat='%Y-%m'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="39b92fba-ca25-42eb-966d-0ec00cd86fb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39b92fba-ca25-42eb-966d-0ec00cd86fb3")) {                    Plotly.newPlot(                        "39b92fba-ca25-42eb-966d-0ec00cd86fb3",                        [{"hovertemplate":"Date=%{x|%Y-%m-%d}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00","2023-01-01T00:00:00","2023-02-01T00:00:00","2023-03-01T00:00:00","2023-04-01T00:00:00","2023-05-01T00:00:00","2023-06-01T00:00:00","2023-07-01T00:00:00","2023-08-01T00:00:00","2023-09-01T00:00:00","2023-10-01T00:00:00","2023-11-01T00:00:00","2023-12-01T00:00:00","2024-01-01T00:00:00","2024-02-01T00:00:00","2024-03-01T00:00:00","2024-04-01T00:00:00","2024-05-01T00:00:00","2024-06-01T00:00:00","2024-07-01T00:00:00","2024-08-01T00:00:00","2024-09-01T00:00:00","2024-10-01T00:00:00","2024-11-01T00:00:00","2024-12-01T00:00:00","2025-01-01T00:00:00","2025-02-01T00:00:00","2025-03-01T00:00:00","2025-04-01T00:00:00","2025-05-01T00:00:00","2025-06-01T00:00:00","2025-07-01T00:00:00","2025-08-01T00:00:00","2025-09-01T00:00:00","2025-10-01T00:00:00","2025-11-01T00:00:00","2025-12-01T00:00:00","2026-01-01T00:00:00","2026-02-01T00:00:00","2026-03-01T00:00:00","2026-04-01T00:00:00","2026-05-01T00:00:00","2026-06-01T00:00:00","2026-07-01T00:00:00","2026-08-01T00:00:00","2026-09-01T00:00:00","2026-10-01T00:00:00","2026-11-01T00:00:00","2026-12-01T00:00:00"],"xaxis":"x","y":[52.0,59.04,62.33,61.72,65.17,71.38,72.49,67.73,71.65,81.48,79.15,71.71,83.22,91.64,108.5,101.78,109.55,114.84,101.62,93.67,84.26,87.55,84.37,76.44,78.12,76.83,73.28,79.45,71.58,70.25,76.07,81.39,89.43,85.64,77.69,71.9,74.15,77.25,81.28,85.35,80.02,79.77,81.8,76.68,70.24,71.99,69.95,70.12,75.74,71.53,68.24,63.54,62.17,68.17,68.39,64.0,60.0,57.0,54.0,51.0,47.0,46.0,45.0,45.0,47.0,47.0,49.0,49.0,48.0,50.0,50.0,50.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555555555 ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Retrieve coefficients from previous step (assuming they are in the global scope)
# a0, a1, rho
# Ensure lag_price is also available, from previous execution it was 1
lag_price = 1

# 1. Get the last historical data point for wells
last_historical_date = combined_df['Date'].max()
last_historical_ln_wells = combined_df['ln_wells'].iloc[-1]
last_historical_wells = combined_df['Wells'].iloc[-1]

# 2. Define the forecast period and get corresponding future prices
# The combined_df ends at last_historical_date. The forecast starts the month after.
forecast_start_date = last_historical_date + pd.DateOffset(months=1)

# Filter df_aug25 for prices relevant to the forecast period.
# We need prices for t-lag, so we need prices up to the end of the forecast period.
# The end of df_aug25 is '2026-08-01'.

future_prices_df = df_aug25[df_aug25['Date'] >= forecast_start_date].copy()

# Calculate ln_price for future prices
future_prices_df['ln_price'] = np.log(future_prices_df['Value'])

# Prepare for iteration
forecasted_ln_wells = []
forecasted_dates = []

# Initialize ln(wells(t-1)) for the first forecast step
current_ln_wells_t_minus_1 = last_historical_ln_wells

# Iterate through the future prices to forecast wells
for i in range(len(future_prices_df)):
    current_date = future_prices_df['Date'].iloc[i]

    # The price for ln(price(t-lag)) needs to be found for the current month being forecast
    # If forecasting for month M, then current_ln_wells_t_minus_1 is from M-1.
    # The price for ln(price(t-lag)) is (M - lag_price) month's price.
    # So, for forecasting wells for current_date (t+1), we need price from current_date - lag_price
    price_date_for_lag = current_date - pd.DateOffset(months=lag_price)

    # Get the ln_price(t-lag) from future_prices_df or combined_df if it's still in the historical range
    if price_date_for_lag >= combined_df['Date'].min(): # check if the price date is within known data
        if price_date_for_lag <= last_historical_date:
            ln_price_t_minus_lag = combined_df[combined_df['Date'] == price_date_for_lag]['ln_price'].iloc[0]
        else:
            ln_price_t_minus_lag = future_prices_df[future_prices_df['Date'] == price_date_for_lag]['ln_price'].iloc[0]
    else:
        # This case should ideally not happen if the forecast period is well-defined
        # relative to price data. For now, we'll use NaN and drop it later, or raise error
        ln_price_t_minus_lag = np.nan

    # If ln_price_t_minus_lag is NaN, we cannot forecast this step.
    if pd.isna(ln_price_t_minus_lag):
        print(f"Warning: Could not find price for {price_date_for_lag}. Stopping forecast.")
        break

    # Apply the regression equation
    # ln(wells(t+1)) = a0 + (a1 * ln(price(t-lag))) + (rho * ln(wells(t-1)))
    predicted_ln_wells_t_plus_1 = a0 + (a1 * ln_price_t_minus_lag) + (rho * current_ln_wells_t_minus_1)

    forecasted_ln_wells.append(predicted_ln_wells_t_plus_1)
    forecasted_dates.append(current_date)

    # Update ln(wells(t-1)) for the next iteration
    current_ln_wells_t_minus_1 = predicted_ln_wells_t_plus_1

# Create a DataFrame for forecasted results
forecast_df = pd.DataFrame({
    'Date': forecasted_dates,
    'ln_wells': forecasted_ln_wells
})
forecast_df['Wells'] = np.exp(forecast_df['ln_wells'])

print("Forecasted Wells (head):")
display(forecast_df.head())

print("Forecasted Wells (tail):")
display(forecast_df.tail())

# Prepare forecast data for plotting to ensure continuity
# Get the last historical point
last_historical_point = combined_df[['Date', 'Wells']].iloc[[-1]]

# Concatenate the last historical point with the forecast_df
# This will make the forecast line start from the last historical point
forecast_plot_df = pd.concat([last_historical_point, forecast_df[['Date', 'Wells']]], ignore_index=True)

# Plotting
plt.figure(figsize=(14, 7))

# Plot historical data
sns.lineplot(x='Date', y='Wells', data=combined_df, marker='o', label='Historical Data', color='blue')

# Plot forecasted data using forecast_plot_df for continuity
sns.lineplot(x='Date', y='Wells', data=forecast_plot_df, marker='x', label='Forecasted Data', color='red', linestyle='--')

plt.axvline(x=last_historical_date, color='grey', linestyle='--', label='End of Historical Data')
plt.title('Historical and Forecasted Well Counts')
plt.xlabel('Date')
plt.ylabel('Well Count')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Forecasted Wells (head):
#         Date  ln_wells       Wells
# 0 2025-08-01  6.149612  468.535699
# 1 2025-09-01  6.136797  462.569689
# 2 2025-10-01  6.119203  454.502408
# 3 2025-11-01  6.104617  447.920841
# 4 2025-12-01  6.089563  441.228751
# Forecasted Wells (tail):
#          Date  ln_wells       Wells
# 12 2026-08-01  6.060148  428.438984
# 13 2026-09-01  6.061025  428.814659
# 14 2026-10-01  6.055809  426.583703
# 15 2026-11-01  6.065852  430.889666
# 16 2026-12-01  6.066670  431.242312

# %%
import statsmodels.api as sm
import numpy as np

# Ensure 'combined_df' is sorted by date
combined_df = combined_df.sort_values(by='Date').reset_index(drop=True)

# Calculate natural logarithms
combined_df['ln_wells'] = np.log(combined_df['Wells'])
combined_df['ln_price'] = np.log(combined_df['Price'])

# Define the lag for price and wells as per the equation
lag_price = 1 # user specified
lag_wells = 1 # fixed at 1 for ln(wells(t-1))

# Create lagged variables
# ln(wells(t+1)) is the dependent variable, so it's ln_wells shifted up by 1 (or current index + 1)
combined_df['ln_wells_t_plus_1'] = combined_df['ln_wells'].shift(-1)
# ln(price(t-lag)) is ln_price shifted down by 'lag_price'
combined_df['ln_price_t_minus_lag'] = combined_df['ln_price'].shift(lag_price)
# ln(wells(t-1)) is ln_wells shifted down by 'lag_wells'
combined_df['ln_wells_t_minus_1'] = combined_df['ln_wells'].shift(lag_wells)

# Drop rows with NaN values resulting from shifting
regression_df = combined_df.dropna().copy()

# Define dependent and independent variables for the regression
Y = regression_df['ln_wells_t_plus_1']
X = regression_df[['ln_price_t_minus_lag', 'ln_wells_t_minus_1']]

# Add a constant to the independent variables for the intercept (a0)
X = sm.add_constant(X)

# Run the OLS regression
model = sm.OLS(Y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# Extract coefficients
a0 = results.params['const']
a1 = results.params['ln_price_t_minus_lag']
rho = results.params['ln_wells_t_minus_1']

print(f"\nDerived Coefficients:")
print(f"a0 (intercept): {a0:.4f}")
print(f"a1 (ln(price(t-lag)) coefficient): {a1:.4f}")
print(f"rho (ln(wells(t-1)) coefficient): {rho:.4f}")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      ln_wells_t_plus_1   R-squared:                       0.269
# Model:                            OLS   Adj. R-squared:                  0.240
# Method:                 Least Squares   F-statistic:                     9.215
# Date:                Fri, 03 Apr 2026   Prob (F-statistic):           0.000392
# Time:                        14:24:47   Log-Likelihood:                 61.909
# No. Observations:                  53   AIC:                            -117.8
# Df Residuals:                      50   BIC:                            -111.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    4.5694      0.545      8.379      0.000       3.474       5.665
# ln_price_t_minus_lag     0.2564      0.082      3.127      0.003       0.092       0.421
# ln_wells_t_minus_1       0.0815      0.105      0.775      0.442      -0.130       0.293
# ==============================================================================
# Omnibus:                        4.986   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.083   Jarque-Bera (JB):                2.333
# Skew:                           0.206   Prob(JB):                        0.311
# Kurtosis:                       2.058   Cond. No.                         396.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Derived Coefficients:
# a0 (intercept): 4.5694
# a1 (ln(price(t-lag)) coefficient): 0.2564
# rho (ln(wells(t-1)) coefficient): 0.0815

# %%
import pandas as pd
import numpy as np

# Provided well count series
wells_series = [383, 275, 475, 452, 426, 408, 444, 430, 441, 546, 446, 486, 448, 433, 477, 501, 502, 537, 550, 560, 519, 577, 527, 500, 538, 437, 570, 514, 535, 444, 512, 503, 464, 556, 451, 441, 482, 515, 503, 542, 503, 471, 563, 508, 470, 518, 503, 440, 480, 480, 460, 458, 447, 445, 445]

# Create a date range for the wells data (Jan 2021 to Jul 2025)
start_date = '2021-01-01'
end_date = '2025-07-01'
date_range = pd.date_range(start=start_date, end=end_date, freq='MS')

# Create a DataFrame for wells data
wells_df = pd.DataFrame({'Date': date_range, 'Wells': wells_series})

# Merge df_aug25 (price data) with wells_df
# Ensure df_aug25 has a 'Date' column for merging
if 'Date' not in df_aug25.columns:
    df_aug25['Date'] = pd.to_datetime(df_aug25['Year'].astype(str) + '-' + df_aug25['Month_Num'].astype(str) + '-01')

# Filter df_aug25 to match the wells data date range
df_aug25_filtered = df_aug25[(df_aug25['Date'] >= start_date) & (df_aug25['Date'] <= end_date)]

# Merge the two DataFrames
# We'll use 'Value' from df_aug25 as 'Price'
combined_df = pd.merge(wells_df, df_aug25_filtered[['Date', 'Value']], on='Date', how='inner')
combined_df.rename(columns={'Value': 'Price'}, inplace=True)

print("Combined DataFrame head:")
display(combined_df.head())

print("Combined DataFrame tail:")
display(combined_df.tail())

print(f"Number of rows in combined_df: {len(combined_df)}")
# Out:
# Combined DataFrame head:
#         Date  Wells  Price
# 0 2021-01-01    383  52.00
# 1 2021-02-01    275  59.04
# 2 2021-03-01    475  62.33
# 3 2021-04-01    452  61.72
# 4 2021-05-01    426  65.17
# Combined DataFrame tail:
#          Date  Wells  Price
# 50 2025-03-01    460  68.24
# 51 2025-04-01    458  63.54
# 52 2025-05-01    447  62.17
# 53 2025-06-01    445  68.17
# 54 2025-07-01    445  68.39
# Number of rows in combined_df: 55
